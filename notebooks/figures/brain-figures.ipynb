# %%
import numpy as np
from os.path import join
from nilearn import plotting

# %%
nifti_dir = '/Users/Katie/Dropbox/Projects/physics-retrieval'
crad = 'craddock2012_tcorr05_2level_270_2mm.nii.gz'
shen = 'shen2015_2mm_268_parcellation.nii.gz'
fig_dir = '/Users/Katie/Dropbox/Projects/physics-retrieval/figures'

# %%
g = plotting.plot_roi(join(nifti_dir, crad), draw_cross=False, cut_coords=(1,-25,11), annotate=False)
g.savefig(join(fig_dir, 'craddock_ortho.png'), dpi=300)

# %%
g = plotting.plot_roi(join(nifti_dir, shen), draw_cross=False, cut_coords=(1,-25,11), annotate=False)
g.savefig(join(fig_dir, 'shen_ortho.png'), dpi=300)
