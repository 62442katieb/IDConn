# %%
import numpy as np
import pandas as pd
import seaborn as sns
import nibabel as nib
import matplotlib.pyplot as plt

from nilearn import plotting
from os.path import join
from glob import glob
from matplotlib.colors import LinearSegmentedColormap

sns.set_context('talk')

# %%
def grab_corr(subjects, nodes, task, condition, session, atlas):
    errors = pd.Series(index=subjects, dtype=str)
    edges = pd.Series(index=subjects, name='edge', dtype=np.float64)
    node1 = nodes[0]
    node2 = nodes[1]
    
    for subject in subjects:
        try:
            if condition != None:
                corrmat = np.genfromtxt(join(data_dir, 
                                             'output/corrmats', 
                                             '{0}-session-{1}_{2}-{3}_{4}-corrmat.csv'.format(subject, 
                                                                                                        session, 
                                                                                                        task, 
                                                                                                        condition, 
                                                                                                        atlas)),
                                        delimiter=' ')
            else:
                corrmat = np.genfromtxt(join(data_dir, 
                                             'output/corrmats', 
                                             '{0}-session-{1}-{2}_network_corrmat_{3}.csv'.format(subject, 
                                                                                                        session, 
                                                                                                        task, 
                                                                                                        atlas)),
                                        delimiter=',')
            edges[subject] = corrmat[node1][node2]
            #post_retr_conn.at[subject] = np.ravel(corrmat, order='F')
        except Exception as e:
            errors[subject] = e
    return edges, errors

# %%
fig_dir = '/Users/kbottenh/Dropbox/Projects/physics-retrieval/figures'
data_dir = '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/'
roi_dir = '/Users/kbottenh/Dropbox/Data/templates/shen2015/'

masks = {'shen2015': '/Users/kbottenh/Dropbox/Projects/physics-retrieval/shen2015_2mm_268_parcellation.nii.gz', 
         'craddock2012': '/Users/kbottenh/Dropbox/Projects/physics-retrieval/craddock2012_tcorr05_2level_270_2mm.nii.gz'}

# %%
bx_dir = '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/rescored'
b_df = pd.read_csv(join(data_dir, 
                        'rescored', 
                        'physics_learning-local_efficiency-BayesianImpute.csv'), 
                   index_col=0, header=0)
drop = b_df.filter(regex='.*lEff.*').columns
b_df.drop(drop, axis=1, inplace=True)

# %%
subgraphs = glob(join(data_dir, 'output', '*sig_edges.csv'))

# %%
subgraphs
# Out:
# ['/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-fci_phys-FSIQ2_Mod-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-fci_phys-FSIQ2_iqXSexXClass-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/shen2015-fci_phys-FSIQ2_StrtLvl-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/shen2015-fci_phys-deltaFSIQ_F-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/shen2015-fci_phys-FSIQ2_SexXClass-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-fci_phys-FSIQ2_SexXClass-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-fci_phys-FSIQ2_F-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-fci_phys-FSIQ2_iqXClass-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-fci_phys-deltaPRI_F-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/shen2015-fci_phys-deltaPRI_SexXClass-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/shen2015-retr_phys-VCI2_fd-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/shen2015-fci_phys-FSIQ2_iqXSexXClass-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-fci_phys-deltaPRI_iqXSexXClass-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-retr_phys-WMI2_fd-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-fci_phys-FSIQ2_iqXSex-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-retr_phys-VCI2_fd-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/craddock2012-fci_phys-deltaFSIQ_SexXClass-sig_edges.csv',
#  '/Users/kbottenh/Dropbox/Projects/physics-retrieval/data/output/shen2015-fci_phys-PRI2_StrtLvl-sig_edges.csv']

# %%
b_df.head()
# Out:
#            Age  Strt.Level  RetrPhyAcc1  RetrPhyAcc2  FCIPhyAcc1  FCIPhyAcc2  \
# 101  20.471233        30.0     0.708333     0.750000    0.333333    0.444444
# 102  21.202740        30.0     0.541667     0.833333    0.222222    0.555556
# 103  18.887671        30.0     0.750000     0.875000    0.444444    0.777778
# 104  21.342466        40.0     0.666667     0.708333    0.444444    0.555556
# 105  20.802740        20.0     0.704523     0.793324    0.509359    0.654661
#
#       VCI1   PRI1   WMI1   PSI1  ...  post phys retr fd  pre phys retr fd  \
# 101  102.0   81.0  100.0  100.0  ...           0.067664          0.055578
# 102  118.0   92.0  117.0   86.0  ...           0.074711          0.133608
# 103  130.0   92.0   89.0   74.0  ...           0.048764          0.053774
# 104  100.0  119.0  105.0   79.0  ...           0.052562          0.058289
# 105  116.0  119.0  117.0   74.0  ...           0.066244          0.065449
#
#      post gen retr fd  pre gen retr fd  post phys fci fd  pre phys fci fd  \
# 101          0.072896         0.070045          0.050342         0.057465
# 102          0.084691         0.137808          0.147811         0.147940
# 103          0.053961         0.055985          0.047358         0.057050
# 104          0.049826         0.063113          0.068322         0.068532
# 105          0.071085         0.071057          0.073068         0.066727
#
#      post ctrl fci fd  pre ctrl fci fd  Sex  Class.Type
# 101          0.093032         0.061562    F         Lec
# 102          0.153425         0.170165    M         Mod
# 103          0.054315         0.055121    M         Lec
# 104          0.064685         0.059499    F         Mod
# 105          0.068098         0.070173    M         Lec
#
# [5 rows x 30 columns]

# %%
iqs = ['VCI', 'WMI', 'PSI', 'PRI', 'FSIQ']
for iq in iqs:
    b_df['delta{0}'.format(iq)] = b_df['{0}2'.format(iq)] - b_df['{0}1'.format(iq)]
    b_df['delta{0}XSex'.format(iq)] = b_df['delta{0}'.format(iq)] * b_df['F']
    b_df['{0}2XSex'.format(iq)] = b_df['{0}2'.format(iq)] * b_df['F']
    b_df['delta{0}XClass'.format(iq)] = b_df['delta{0}'.format(iq)] * b_df['Mod']
    b_df['{0}2XClass'.format(iq)] = b_df['{0}2'.format(iq)] * b_df['Mod']
    b_df['SexXClass'] = b_df['F'] * b_df['Mod']
    b_df['delta{0}XSexXClass'.format(iq)] = b_df['delta{0}'.format(iq)] * b_df['SexXClass']
    b_df['{0}2XSexXClass'.format(iq)] = b_df['{0}2'.format(iq)] * b_df['SexXClass']

# %%
husl_pal = sns.husl_palette(h=0, n_colors=268)
crayons_l = sns.crayon_palette(['Vivid Tangerine', 'Cornflower'])
crayons_d = sns.crayon_palette(['Brick Red', 'Midnight Blue'])
grays = sns.light_palette('#999999', n_colors=3, reverse=True)

f_2 = sns.crayon_palette(['Red Orange', 'Vivid Tangerine'])
m_2 = sns.crayon_palette(['Cerulean', 'Cornflower'])

# %%
node_size = 15
plt.tight_layout(pad=1.5)
for subgraph in subgraphs:
    regression = subgraph[63:-4]
    print(regression)
    keys = regression.split('-')
    mask = keys[0]
    condition = 'Physics'
    task = keys[1].split('_')[0]
    iq = keys[2].split('_')[0]
    cov = keys[2].split('_')[1]
    print(iq)
    
    coordinates = plotting.find_parcellation_cut_coords(labels_img=masks[mask])
    
    conns = pd.read_csv(subgraph, index_col=0, header=0)
    for i in conns.index:
        conns.at[i, 'x'] = coordinates[i-1][0]
        conns.at[i, 'y'] = coordinates[i-1][1]
        conns.at[i, 'z'] = coordinates[i-1][2]
    conns.set_index([conns.index, 'x', 'y', 'z'], inplace=True)
    q = plotting.plot_connectome(conns, coordinates, node_size=node_size, 
                                 edge_threshold=2., edge_vmax=7., edge_cmap='PuOr_r', )
    q.savefig(
        join(fig_dir, '{0}.png'.format(regression)), dpi=300)
    q.close()
    conns.dropna(how='all', axis=0, inplace=True)
    conns.dropna(how='all', axis=1, inplace=True)
    conns.fillna(0, inplace=True)
    conns.sort_index(axis=0, ascending=True, inplace=True)
    conns.sort_index(axis=1, ascending=True, inplace=True)
    conns.index.rename(['idx', 'x', 'y', 'z'], inplace=True)
    nodes = list(conns.index.get_level_values('idx').astype(str))
    hmap_mask = np.triu(np.ones_like(conns.values, dtype=np.bool))
    
    if conns.max().max() > 0:
        cmap = 'Oranges'
        one = conns.idxmax(axis=0)
        two = conns.idxmax(axis=1)
    else:
        cmap = 'Purples_r'
        one = conns.idxmin(axis=0)
        two = conns.idxmin(axis=1)
    edges = []
    for column in conns.columns:
        ind = conns[conns[column] != 0].index
        for i in ind:
            #print(column, i[0])
            edges.append((int(column), i[0]))

    for edge in edges:
        print(regression, edge)
        sns.axes_style('ticks')
        edges, error = grab_corr(b_df.index, edge, task, 'Physics', '1', mask)
        scatter_df = pd.concat([edges, b_df[[iq, 'F', 'Mod']]], axis=1)

        if 'iq' in cov:
            cov = cov.replace('iq', iq)
            if 'Sex' in cov:
                if not 'Class' in cov:
                    print('Sex interaction:', regression)
                    h = sns.lmplot(iq, 'edge', data=scatter_df, hue_order=[0.,1.],
                                   hue='F', palette=crayons_d, height=6)
                    h.savefig(join(fig_dir, '{0}-{1}-scatter.png'.format(regression, edge)), dpi=300)
                    plt.close()
                else:
                    print('SexXClass interaction:', regression)
                    h = sns.lmplot(iq, 'edge', data=scatter_df[scatter_df['F'] == 1], 
                                   hue_order=[0.,1.], hue='Mod', palette=f_2, height=6)
                    h.savefig(join(fig_dir, '{0}-{1}-scatter-f.png'.format(regression, edge)), 
                              dpi=300)
                    h = sns.lmplot(iq, 'edge', data=scatter_df[scatter_df['F'] == 0], 
                                   hue_order=[0.,1.], hue='Mod', palette=m_2, height=6)
                    h.savefig(join(fig_dir, '{0}-{1}-scatter-m.png'.format(regression, edge)), 
                              dpi=300)
                    plt.close()

            elif 'Class' in cov:
                if not 'Sex' in cov:
                    print('Class interaction:', regression)
                    h = sns.lmplot(iq, 'edge', data=scatter_df, hue='Mod', hue_order=[0.,1.],
                                   palette=grays, height=6)
                    h.savefig(join(fig_dir, '{0}-{1}-scatter.png'.format(regression, edge)), dpi=300)
                    plt.close()

            else:
                print('No interaction:', regression)
                fig1,ax1 = plt.subplots(figsize=(6,6))
                sns.regplot(scatter_df[iq], scatter_df['edge'], color='0.5')
                sns.despine()
                ax1.set_title('{0}X{1} connectivity'.format(regression, edge))
                plt.tight_layout()
                fig1.savefig(join(fig_dir, '{0}-{1}-scatter.png'.format(regression, edge)), dpi=300)
                plt.close()
    sns.axes_style("white")
    fig, ax = plt.subplots()
    g = sns.heatmap(conns[nodes], mask=hmap_mask, square=True, vmax=7.,
                    cmap='PuOr_r', linecolor='1.0', linewidths=1, center=0, cbar_kws={"shrink": .75})
    g.set_yticklabels(labels=nodes, rotation=0)
    g.set_title(regression)
    fig.savefig(join(fig_dir, '{0}-heatmap.png'.format(regression)), dpi=300)
    plt.close()

    rois = None
    roi_nifti = nib.load(join(roi_dir, 'roi{0}.nii.gz'.format(int(nodes[0]))))
    roi = roi_nifti.get_fdata()
    rois = (roi * float(nodes[0]))
    if len(nodes) > 1:
        for node in nodes[1:]:
            roi_nifti = nib.load(
                join(roi_dir, 'roi{0}.nii.gz'.format(int(node))))
            roi = roi_nifti.get_fdata()
            rois += (roi * int(node))
    else:
        pass
    rois_nifti = nib.Nifti1Image(rois, roi_nifti.affine)
    rois_nifti.to_filename(join(data_dir, '{0}_nodes.nii.gz'.format(regression)))
    h = plotting.plot_glass_brain(rois_nifti, cmap=LinearSegmentedColormap.from_list(
        husl_pal, husl_pal, N=268), vmin=0, vmax=268)
    h.savefig(join(fig_dir, '{0}_ROIs.png'.format(regression)), dpi=300)
    plt.close()
    h.close()
# Out:
# craddock2012-fci_phys-FSIQ2_Mod-sig_edges
# FSIQ2
# craddock2012-fci_phys-FSIQ2_Mod-sig_edges (234, 52)
# craddock2012-fci_phys-FSIQ2_Mod-sig_edges (52, 234)
# craddock2012-fci_phys-FSIQ2_iqXSexXClass-sig_edges
# FSIQ2
# craddock2012-fci_phys-FSIQ2_iqXSexXClass-sig_edges (18, 199)
# SexXClass interaction: craddock2012-fci_phys-FSIQ2_iqXSexXClass-sig_edges
# craddock2012-fci_phys-FSIQ2_iqXSexXClass-sig_edges (199, 18)
# craddock2012-fci_phys-FSIQ2_iqXSexXClass-sig_edges (234, 52)
# craddock2012-fci_phys-FSIQ2_iqXSexXClass-sig_edges (52, 234)
# shen2015-fci_phys-FSIQ2_StrtLvl-sig_edges
# FSIQ2
# shen2015-fci_phys-FSIQ2_StrtLvl-sig_edges (134, 258)
# shen2015-fci_phys-FSIQ2_StrtLvl-sig_edges (258, 134)
# shen2015-fci_phys-deltaFSIQ_F-sig_edges
# deltaFSIQ
# shen2015-fci_phys-deltaFSIQ_F-sig_edges (10, 34)
# shen2015-fci_phys-deltaFSIQ_F-sig_edges (34, 10)
# shen2015-fci_phys-FSIQ2_SexXClass-sig_edges
# FSIQ2
# shen2015-fci_phys-FSIQ2_SexXClass-sig_edges (147, 36)
# shen2015-fci_phys-FSIQ2_SexXClass-sig_edges (36, 147)
# craddock2012-fci_phys-FSIQ2_SexXClass-sig_edges
# FSIQ2
# craddock2012-fci_phys-FSIQ2_SexXClass-sig_edges (18, 199)
# craddock2012-fci_phys-FSIQ2_SexXClass-sig_edges (199, 18)
# craddock2012-fci_phys-FSIQ2_SexXClass-sig_edges (234, 52)
# craddock2012-fci_phys-FSIQ2_SexXClass-sig_edges (52, 234)
# craddock2012-fci_phys-FSIQ2_F-sig_edges
# FSIQ2
# craddock2012-fci_phys-FSIQ2_F-sig_edges (115, 152)
# craddock2012-fci_phys-FSIQ2_F-sig_edges (152, 115)
# craddock2012-fci_phys-FSIQ2_F-sig_edges (18, 199)
# craddock2012-fci_phys-FSIQ2_F-sig_edges (199, 18)
# craddock2012-fci_phys-FSIQ2_iqXClass-sig_edges
# FSIQ2
# craddock2012-fci_phys-FSIQ2_iqXClass-sig_edges (234, 52)
# Class interaction: craddock2012-fci_phys-FSIQ2_iqXClass-sig_edges
# craddock2012-fci_phys-FSIQ2_iqXClass-sig_edges (52, 234)
# craddock2012-fci_phys-deltaPRI_F-sig_edges
# deltaPRI
# craddock2012-fci_phys-deltaPRI_F-sig_edges (128, 22)
# craddock2012-fci_phys-deltaPRI_F-sig_edges (22, 128)
# shen2015-fci_phys-deltaPRI_SexXClass-sig_edges
# deltaPRI
# shen2015-fci_phys-deltaPRI_SexXClass-sig_edges (204, 229)
# shen2015-fci_phys-deltaPRI_SexXClass-sig_edges (229, 204)
# shen2015-retr_phys-VCI2_fd-sig_edges
# VCI2
# shen2015-retr_phys-VCI2_fd-sig_edges (145, 35)
# shen2015-retr_phys-VCI2_fd-sig_edges (35, 145)
# shen2015-fci_phys-FSIQ2_iqXSexXClass-sig_edges
# FSIQ2
# shen2015-fci_phys-FSIQ2_iqXSexXClass-sig_edges (147, 36)
# SexXClass interaction: shen2015-fci_phys-FSIQ2_iqXSexXClass-sig_edges
# shen2015-fci_phys-FSIQ2_iqXSexXClass-sig_edges (36, 147)
# craddock2012-fci_phys-deltaPRI_iqXSexXClass-sig_edges
# deltaPRI
# craddock2012-fci_phys-deltaPRI_iqXSexXClass-sig_edges (165, 168)
# SexXClass interaction: craddock2012-fci_phys-deltaPRI_iqXSexXClass-sig_edges
# craddock2012-fci_phys-deltaPRI_iqXSexXClass-sig_edges (168, 79)
# craddock2012-fci_phys-deltaPRI_iqXSexXClass-sig_edges (168, 165)
# craddock2012-fci_phys-deltaPRI_iqXSexXClass-sig_edges (79, 168)
# craddock2012-retr_phys-WMI2_fd-sig_edges
# WMI2
# craddock2012-retr_phys-WMI2_fd-sig_edges (126, 178)
# craddock2012-retr_phys-WMI2_fd-sig_edges (136, 62)
# craddock2012-retr_phys-WMI2_fd-sig_edges (178, 86)
# craddock2012-retr_phys-WMI2_fd-sig_edges (178, 126)
# craddock2012-retr_phys-WMI2_fd-sig_edges (191, 93)
# craddock2012-retr_phys-WMI2_fd-sig_edges (62, 136)
# craddock2012-retr_phys-WMI2_fd-sig_edges (86, 178)
# craddock2012-retr_phys-WMI2_fd-sig_edges (93, 191)
# craddock2012-fci_phys-FSIQ2_iqXSex-sig_edges
# FSIQ2
# craddock2012-fci_phys-FSIQ2_iqXSex-sig_edges (18, 199)
# Sex interaction: craddock2012-fci_phys-FSIQ2_iqXSex-sig_edges
# craddock2012-fci_phys-FSIQ2_iqXSex-sig_edges (199, 18)
# craddock2012-retr_phys-VCI2_fd-sig_edges
# VCI2
# craddock2012-retr_phys-VCI2_fd-sig_edges (126, 178)
# craddock2012-retr_phys-VCI2_fd-sig_edges (178, 86)
# craddock2012-retr_phys-VCI2_fd-sig_edges (178, 126)
# craddock2012-retr_phys-VCI2_fd-sig_edges (179, 9)
# craddock2012-retr_phys-VCI2_fd-sig_edges (191, 93)
# craddock2012-retr_phys-VCI2_fd-sig_edges (256, 76)
# craddock2012-retr_phys-VCI2_fd-sig_edges (76, 256)
# craddock2012-retr_phys-VCI2_fd-sig_edges (86, 178)
# craddock2012-retr_phys-VCI2_fd-sig_edges (9, 179)
# craddock2012-retr_phys-VCI2_fd-sig_edges (93, 191)
# craddock2012-fci_phys-deltaFSIQ_SexXClass-sig_edges
# deltaFSIQ
# craddock2012-fci_phys-deltaFSIQ_SexXClass-sig_edges (156, 44)
# craddock2012-fci_phys-deltaFSIQ_SexXClass-sig_edges (44, 156)
# shen2015-fci_phys-PRI2_StrtLvl-sig_edges
# PRI2
# shen2015-fci_phys-PRI2_StrtLvl-sig_edges (134, 258)
# shen2015-fci_phys-PRI2_StrtLvl-sig_edges (258, 134)

# %%
# Out:
#          edge        PRI2    F  Mod
# 101  0.550654  102.000000  1.0  0.0
# 102  0.355383  100.000000  0.0  1.0
# 103  0.526820  104.000000  0.0  0.0
# 104  0.457468  123.000000  1.0  1.0
# 105       NaN  113.085049  0.0  0.0
# ..        ...         ...  ...  ...
# 629  0.323534  117.000000  0.0  1.0
# 630  0.576499  131.000000  0.0  1.0
# 631  0.461101  100.000000  1.0  1.0
# 633  0.506347  109.000000  0.0  1.0
# 634  0.621709  135.000000  0.0  0.0
#
# [130 rows x 4 columns]
